# %%
import pandas as pd
import numpy as np

# %%
sites = [
    {
         "ip": "192.168.0.26",
         "port": "80",
         "name": "Kadoma"
    },
     {
         "ip": "192.168.0.33",
         "port": "80",
         "name": "Marondera"
    },
     {
         "ip": "192.168.0.36",
         "port": "80",
         "name": "Bindura"
    },
     {
         "ip": "192.168.0.46",
         "port": "80",
         "name": "NVRL"
    },
     {
         "ip": "192.168.0.47",
         "port": "80",
         "name": "AIBST"
    },
     {
         "ip": "192.168.0.48",
         "port": "80",
         "name": "BRTI"
    },
     {
         "ip": "192.168.0.49",
         "port": "80",
         "name": "ThornGrove"
    },
     {
         "ip": "192.168.0.51",
         "port": "80",
         "name": "Gwanda"
    },
     { 
         "ip": "192.168.0.53",
         "port": "80",
         "name": "VicFalls"
    },
     {
         "ip": "192.168.0.57",
         "port": "80",
         "name": "Beightbridge"
    },
    {
        "ip": "192.168.0.32",
        "port": "80",
        "name": "NMRL"
   },
    {
        "ip": "196.27.113.154",
        "port": "5443",
        "name": "BRIDH"
   },

    {
        "ip": "194.133.159.134",
        "port": "3443",
        "name": "Mutare"
   },
    {
        "ip": "196.27.127.58",
        "port": "4343",
        "name": "NTBRL"
   },
    {
        "ip": "196.27.127.58",
        "port": "5143",
        "name": "Lupane"
   },
    {
        "ip": "197.155.235.2",
        "port": "3443",
        "name": "Masvingo"
   },
]

# %%
for site in sites:
    data = pd.read_csv(f"{site['ip']}:{site['port']}-contact.csv", sep=",")
    with_emails = data.dropna(subset=['EmailAddress'])
    with_mobile = data.dropna(subset=['MobilePhone'])
    #
    print(f"{site['name']}: Emails:  {with_emails.shape[0]}  Phones:  {with_mobile.shape[0]} \n")
# Out:
# Kadoma: Emails:  53  Phones:  204
#
# Marondera: Emails:  55  Phones:  203
#
# Bindura: Emails:  56  Phones:  203
#
# NVRL: Emails:  209  Phones:  218
#
# AIBST: Emails:  215  Phones:  223
#
# BRTI: Emails:  214  Phones:  220
#
# ThornGrove: Emails:  53  Phones:  203
#
# Gwanda: Emails:  58  Phones:  215
#
# VicFalls: Emails:  53  Phones:  208
#
# Beightbridge: Emails:  53  Phones:  203
#
# NMRL: Emails:  266  Phones:  249
#
# BRIDH: Emails:  52  Phones:  202
#
# Mutare: Emails:  52  Phones:  205
#
# NTBRL: Emails:  124  Phones:  16
#
# Lupane: Emails:  58  Phones:  215
#
# Masvingo: Emails:  11  Phones:  0

# %%
import pandas as pd
import uuid

# %%
data = pd.read_csv("client.csv")

# %%
data.head(2)
# Out:
#          province_name                           province_id distrct_name  \
# 0  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
# 1  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
#
#                             district_it                          name  \
# 0  fe0e408d-a186-45ac-a4ea-7479e856e38c  Beitbridge District Hospital
# 1  fe0e408d-a186-45ac-a4ea-7479e856e38c         Beitbridge NRZ Clinic
#
#        code created_by         created_date last_modified_by  \
# 0  ZW06010A      admin  2021-04-07 12:00:42            admin
# 1  ZW060181      admin  2021-04-07 12:00:43            admin
#
#     last_modified_date  client_uid
# 0  2021-04-07 12:00:42         NaN
# 1  2021-04-07 12:00:43         NaN

# %%
data['client_uid'] = data.apply(lambda x: uuid.uuid4(), axis=1)

# %%
data.head(5)
# Out:
#          province_name                           province_id distrct_name  \
# 0  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
# 1  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
# 2  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
# 3  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
# 4  Matabeleland South   ce996046-d27c-4349-badb-beaf925d9b98  Beitbridge
#
#                             district_it                          name  \
# 0  fe0e408d-a186-45ac-a4ea-7479e856e38c  Beitbridge District Hospital
# 1  fe0e408d-a186-45ac-a4ea-7479e856e38c         Beitbridge NRZ Clinic
# 2  fe0e408d-a186-45ac-a4ea-7479e856e38c         Beitbridge ZRP Clinic
# 3  fe0e408d-a186-45ac-a4ea-7479e856e38c            Chamnangana Clinic
# 4  fe0e408d-a186-45ac-a4ea-7479e856e38c              Chaswingo Clinic
#
#        code created_by         created_date last_modified_by  \
# ...

# %%
data.tail(5)
# Out:
#      province_name                           province_id distrct_name  \
# 1550     Midlands   39ce0e37-9e7b-4bc1-882d-64846ba6821c  Zvishavane
# 1551     Midlands   39ce0e37-9e7b-4bc1-882d-64846ba6821c  Zvishavane
# 1552     Midlands   39ce0e37-9e7b-4bc1-882d-64846ba6821c  Zvishavane
# 1553     Midlands   39ce0e37-9e7b-4bc1-882d-64846ba6821c  Zvishavane
# 1554     Midlands   39ce0e37-9e7b-4bc1-882d-64846ba6821c  Zvishavane
#
#                                district_it                          name  \
# 1550  59ee45c1-91b0-4aa8-8e3d-195eba0e2086                 Welezi Clinic
# 1551  59ee45c1-91b0-4aa8-8e3d-195eba0e2086  ZPS Zvishavane Prison Clinic
# 1552  59ee45c1-91b0-4aa8-8e3d-195eba0e2086  Zvishavane District Hospital
# 1553  59ee45c1-91b0-4aa8-8e3d-195eba0e2086     Zvishavane Medical Centre
# 1554  59ee45c1-91b0-4aa8-8e3d-195eba0e2086         Zvishavane ZRP Clinic
#
#           code created_by           created_date last_modified_by  \
# ...
